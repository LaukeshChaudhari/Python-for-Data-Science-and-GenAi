# %% [markdown]
# #### Standard Library Overview
#
# Pythons Standard Library is a vast collection of modules and packages that comes bundled with Pyhthon, providing a wide range of functionalities out of the box.

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
# random

import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 7
# banana

# %%
# File and Directory Access 

import os 
print(os.getcwd())
# Out:
# d:\Python\5-Modules

# %%
os.mkdir('test_dir')

# %%
# High level operations on files and collection of files
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
# Data Serialization
import json
data={'name':'Love','age':23}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Love", "age": 23}
# <class 'str'>
# {'name': 'Love', 'age': 23}
# <class 'dict'>

# %%
# csv

import csv

with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(["Love",23])

with open('example.csv','r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Love', '23']

# %%
# datetime
from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2025-01-06 17:32:34.149295
# 2025-01-05 17:32:34.149295

# %%
# time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1736165030.2988403
# 1736165032.299922

# %%
# Regular expression
import re

pattern=r'\d+'
text='There are 123 apples'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
