# %% [markdown]
# #### Decorators
#
# Decoraters are a powerful and flexible features in Python that allows you to modify the behaviour of a function or class method. They are commonly used to add functionality to functions or methods without modifying their actual code.

# %%
# Function copy
# closures
# decoraters

# %%
# function copy
def welcome():
    return "Welcome to the advanced python course"

welcome()
# Out:
# 'Welcome to the advanced python course'

# %%
wel=welcome
print(wel())

del welcome
print(wel())
# Out:
# Welcome to the advanced python course
# Welcome to the advanced python course

# %%
# closures functions

def main_welcome(msg):

    def sub_welcome_method():
        print("Welcome to the advanced python course")
        print(msg)
        print("Please learn these concepts properly !")
    return sub_welcome_method()

# %%
main_welcome("welcome everyone")
# Out:
# Welcome to the advanced python course
# welcome everyone
# Please learn these concepts properly !

# %%
def main_welcome(func,lst):

    def sub_welcome_method():
        print("Welcome to the advanced python course")
        print(func(lst))
        print("Please learn these concepts properly !")
    return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4,5])
# Out:
# Welcome to the advanced python course
# 5
# Please learn these concepts properly !

# %%
len([1,2,3,4,5,6])
# Out:
# 6

# %%
# Decorater
def main_welcome(func):

    def sub_welcome_method():
        print("Welcome to the advanced python course")
        func()
        print("Please learn these concepts properly !")
    return sub_welcome_method()

# %%
def course_introduction():
    print("This is an advanced python course")

course_introduction()
# Out:
# This is an advanced python course

# %%
main_welcome(course_introduction)
# Out:
# Welcome to the advanced python course
# This is an advanced python course
# Please learn these concepts properly !

# %%
@main_welcome
def course_introduction():
    print("This is an advanced python course")
# Out:
# Welcome to the advanced python course
# This is an advanced python course
# Please learn these concepts properly !

# %%
# Decorater

def my_decorater(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

# %%
@my_decorater
def say_hello():
    print("Hello")

# %%
say_hello()
# Out:
# Something is happening before the function is called.
# Hello
# Something is happening after the function is called.

# %%
# Decoraters and Arguments
def repeat(n):
    def decorater(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorater

# %%
@repeat(3)
def say_hello():
    print("hello")

# %%
say_hello()
# Out:
# hello
# hello
# hello

# %% [markdown]
# #### Conclusion
#
# Decoraters are a powerful tool in Python for extending and modifying the behavior of functions and methods. They provide a clean and readable way to add functionality such as logging, timing, access control, and more without changing the original code. Understanding and using decoraters effectively can significantly enhance your Python programming skills.
