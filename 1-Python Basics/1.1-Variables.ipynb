# %% [markdown]
# # Variables
#
# Variables are fundamental elements in programming use to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them, and they do not need declaration to reserve memory space. The declaration happens automatically when you assign a value to a variable.

# %%
a = 100

# %%
# Declaring And Assigning Variables

age = 32
height = 6.1
name="Laukesh"

# printing the variable 

print("age :",age)
print("height ",height)
print("Name :",name)
# Out:
# age : 32
# height  6.1
# Name : Laukesh

# %%
# Naming Conventions
# Variable names should be descriptive
# They must start with a letter or an '_' nad contains letter, numbers and underscores
# variables names case sensitive
 
# valid variable names

first_name="Laukesh"
last_name="Chaudhari"

# %%
# Case Sensitive
name = "Laueksh"
Name = "Chaudhari"

# %%
# Understanding Variables types
# Python is dynamically typed, tyoe of a varible is determined at runtime

age = 25 # int
height = 9999.1111 # float
name = "Laukesh" # str
is_student = True # bool

print(type(name))
print(type(height))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# Type Checking and conversion

type(height)
# Out:
# float

# %%
age = 25.47
print(type(age))

# Type conversion
age_str=str(age)
print(age_str)
print(type(age_str))

age_float=int(age)
print(type(age_float))
print(age_float)
# Out:
# <class 'float'>
# 25.47
# <class 'str'>
# <class 'int'>
# 25

# %%
age = '25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
height=5.11
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 5.0

# %%
# Type Conversion 
a = 5
b = 4

sum = (a + b)
print(type(str(sum)))
print(type(sum))
print(sum)

diff = (a - b)
print(type(float(diff)))
print(diff)

mult = float(a * b)
# print(float(mult))
print(mult)

div = str(a / b)
print(type(div))
print(div)
# Out:
# <class 'str'>
# <class 'int'>
# 9
# <class 'float'>
# 1
# 20.0
# <class 'str'>
# 1.25

# %%
a = ("2")
b = 4.25

print(type(a))
print(int(a) + int(b))
# Out:
# <class 'str'>
# 6

# %%
# Dyanmic Typing
# Python allows the type of a variable to change as the program executes 

var = 10 # int
print(var,type(var))

var = "Hello"
print(var,type(var))

var = 3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
# input

age=(input("What is the age"))
print(age,type(age))
# Out:
# 15 <class 'str'>

# %%
name = input("enter your name")
print("Welcome",name)
# Out:
# Welcome Love

# %%
val = float(input("enter some value: "))
print(type(val),val)
# Out:
# <class 'float'> 25.0

# %%
name = input("enter name: ")
age = int(input("enter age: "))
marks = float(input("enter marks: "))

print("welcome: "),name
print("age: ",age)
print("marks: ",marks)
# Out:
# welcome:
# age:  23
# marks:  76.2

# %%
# arithmatic operator

a = 5
b = 2

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b) # Remainder
print(a ** b) #a ^ b
# Out:
# 7
# 3
# 10
# 2.5
# 1
# 25

# %%
# relational operators
a = 50
b = 20

print(a == b)
print(a != b) # Not Equal to
print(a >= b)
print(a <= b)
print(a > b)
print(a < b)
# Out:
# False
# True
# True
# False
# True
# False

# %%
# assignment operator
num = 10
num = num + 10
print("num: ",num)
num+=10
print("num: ",num)
num-=10
print("num: ",num)
num*=10
print("num: ",num)
num/=10
print("num: ",num)
num%=5
print("num: ",num)
num = 2
num**=5
print("num: ",num)
# Out:
# num:  20
# num:  30
# num:  20
# num:  200
# num:  20.0
# num:  0.0
# num:  32

# %%
# Logical Operator
a = 50
b = 50
c = 70

print("AND operator:", (a == b) and (a < c) and (b < c))

print(not False)
print(not (a < b))

val1 = True
val2 = True
print("AND operator:",val1 and val2)

print("OR operator:",val1 or val2)

print("OR operator:",(a != b) or (a > c) or (b > c))
# Out:
# AND operator: True
# True
# True
# AND operator: True
# OR operator: True
# OR operator: False

# %%
first = int(input("enter first : "))
second = int(input("enter second : "))

print("sum = ",first + second)
# Out:
# sum =  30

# %%
a = int(input("enter first : "))
b = int(input("enter second : "))

print("avg =",(a+b)/2)
# Out:
# avg = 15.0

# %%
a = int(input("enter first : "))
b = int(input("enter second : "))

print(a >= b)
# Out:
# False

# %%
side = float(input("enter square side : "))

print("area = ",side**2)
# Out:
# area =  100.0

# %%
# Simple Calculator 

num1 =  float(input("Enter first number : "))
num2 = float(input("Enter Second Number: "))

sum = num1 + num2
difference =  num1 - num2
product = num1 * num2
quotient = num1/num2

print("Sum:", sum)
print("Difference:" ,difference)
print("Product:", product)
print("Quotient:", quotient)
# Out:
# Sum: 36.0
# Difference: -12.0
# Product: 288.0
# Quotient: 0.5

# %% [markdown]
# # Conclusion :
#
# Varibles are essentials in Python Programming for storing and manipualting data. Understanding how to declare, assign, and use variables effectively is crucial for writing functional and efficient code. Following proper naming convention amd understanding variable types will help in maintaining readability and consistency in your code
