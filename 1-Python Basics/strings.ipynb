# %%
str1 = "this is a string"
str2 = 'LoveChaudhari'
str3 = """This is a string"""

# %%
str1 = "This is atring.\nWe are creating it in python."
print(str1)
# Out:
# This is atring.
# We are creating it in python.

# %%
str1 = "Love"
str2 = 'Chaudhari'

print(str1+str2)
# Out:
# LoveChaudhari

# %%
str1 = "Love"
len1 = len(str1)
print(len1)
str2 = 'Chaudhari'
len2 = len(str2)
print(len2)

print(str1+str2)
# Out:
# 4
# 9
# LoveChaudhari

# %%
str = 'LoveChaudhari'
print(str[5:len(str)])
print(str[5:])
print(str[:4])
# Out:
# haudhari
# haudhari
# Love

# %%
str = "LoveP"
print(str[-5:-2])
# Out:
# Lov

# %%
str = "i am studying python from LoveKesh"
print(str.endswith("app"))
print(str.capitalize())
print(str.replace("o","a"))
print(str.find("a"))
print(str.count("a"))
# Out:
# False
# I am studying python from lovekesh
# i am studying pythan fram LaveKesh
# 2
# 1

# %%
firstname=(input("enter first name : "))
# leng=len(firstname)

print("length of string is",len(firstname))
# Out:
# length of string is 4

# %%
str = "Hi $Iam the $ symbol $99.99"
print(str.count("$"))
# Out:
# 3
